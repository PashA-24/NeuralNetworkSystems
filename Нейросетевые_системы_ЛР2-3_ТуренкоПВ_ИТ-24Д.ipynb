# %% [markdown]
# ## Лабораторная работа №3 "Апроксимация нелинейных функций"

# %% [markdown]
# **Цель работы:** изучить построение полносвязных нейронных сетей для аппроксимации нелинейной функции и сравнить обычную последовательную архитектуру с ветвящейся сетью.

# %% [markdown]
# ## Теоретические сведения
#
# Полносвязная нейронная сеть (многослойный персептрон) решает задачу аппроксимации как задачу обучения отображения
# $(t \mapsto f(t))$ по набору примеров «аргумент–значение функции».
# Сеть получает на вход значения аргумента, на выходе должна воспроизводить значения функции, а параметры подбираются
# так, чтобы средняя ошибка между предсказанием и эталоном была минимальной.
#
# В качестве функции \(f(t)\) можно использовать любую одномерную нелинейную зависимость. В данной работе в качестве
# теста берётся функция `sin(2πt)`, но полученные модели так же применимы для аппроксимации других сигналов.
#
# Важную роль играют нелинейные функции активации. Если между линейными слоями не использовать нелинейность, то вся сеть
# сведётся к одному линейному преобразованию и не сможет описывать сложную зависимость. В работе используется `Tanh`,
# подходящая для гладких нелинейных функций.
#
# В Keras данные обычно подаются в виде массивов NumPy, архитектура сети задаётся через Sequential или Functional API,
# а обновление параметров выполняет оптимизатор (например, `Adam`). В качестве функции потерь при аппроксимации удобно
# использовать среднеквадратичную ошибку `mse`.

# %% [markdown]
# ## Лабораторная работа №2. Часть 1

# %%
# Установка дополнительных пакетов
# !pip install tensorflow pydot
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: pyparsing>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pydot) (3.3.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
# Базовые библиотеки
import math
import numpy as np
import matplotlib.pyplot as plt

# Keras / TensorFlow
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils

# %%
# Создание обучающей выборки
t0 = np.arange(0, 1, 0.001, dtype=np.float32)
t  = 2 * math.pi * t0
x  = np.sin(t).astype(np.float32)

# Прорисовка графиков обучающей выборки
plt.figure(figsize=(15, 10))

plt.subplot(2, 1, 1)
plt.plot(t0, t, "b", linewidth=5)
plt.title("График входного сигнала t = 2πt0", fontsize=16)
plt.ylabel("t", fontsize=16)
plt.xlabel("t0", fontsize=16)
plt.grid()

plt.subplot(2, 1, 2)
plt.plot(t0, x, "b", linewidth=5)
plt.title("График аппроксимируемой функции", fontsize=16)
plt.ylabel("x", fontsize=16)
plt.xlabel("t0", fontsize=16)
plt.grid()

plt.subplots_adjust(wspace=0, hspace=0.3)  # задаёт зазор между графиками
plt.show()

# %%
# Модель полносвязной сети для аппроксимации функции
def NN_sin_sequential(in_parameters: int):
    model = Sequential([
        Dense(50, activation="relu", input_shape=(in_parameters,)),
        Dense(50, activation="relu"),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=0.01), loss="mse")
    return model

# %%
def NN_sin_functional(in_shape):
    model_input = Input(shape=in_shape)
    x = Dense(50, activation="relu")(model_input)
    x = Dense(50, activation="relu")(x)
    model_out = Dense(1)(x)

    model = Model(model_input, model_out, name="NNSin_Functional")
    model.compile(optimizer=Adam(learning_rate=0.01), loss="mse")
    return model

# %%
# Создание моделей (обычный Sequential и Functional API)
model_sin_seq = NN_sin_sequential(1)
model_sin = NN_sin_functional((1,))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Вывод структуры НС
print("=== Структура модели (Sequential) ===")
model_sin_seq.summary()

print("\n=== Структура модели (Functional API) ===")
model_sin.summary()
utils.plot_model(model_sin, dpi=60, show_shapes=True)
# Out:
# === Структура модели (Sequential) ===
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,701 (10.55 KB)
#  Trainable params: 2,701 (10.55 KB)
#  Non-trainable params: 0 (0.00 B)
# === Структура модели (Functional API) ===
# Model: "NNSin_Functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,701 (10.55 KB)
#  Trainable params: 2,701 (10.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Подготовка данных для Keras
# t0  – значения аргумента (от 0 до 1 с шагом 0.001)
# x   – значения аппроксимируемой функции sin(2πt)
X_train = t0.reshape(-1, 1)
y_train = x.reshape(-1, 1)

# Параметры обучения
n_epochs   = 100         # число проходов по всему набору данных
batch_size = 30          # размер мини‑батча

history_obj = model_sin.fit(
    X_train, y_train,
    epochs=n_epochs,
    batch_size=batch_size,
    verbose=0
)
history = history_obj.history['loss']

for epoch in range(19, n_epochs, 20):       # периодический вывод прогресса
    print(f"Epoch {epoch+1:3d}/{n_epochs}, loss = {history[epoch]:.6f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1681/3463366676.py in <cell line: 0>()
#       9 batch_size = 30          # размер мини‑батча
#      10
# ---> 11 history_obj = model_sin.fit(
#      12     X_train, y_train,
#      13     epochs=n_epochs,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Вывод графика процесса обучения
plt.figure(figsize=(14, 7))
plt.plot(history, label='Ошибка на обучающем наборе')
plt.ylabel('Средняя ошибка (MSE)', fontsize=14)
plt.xlabel('Эпоха', fontsize=14)
plt.grid()
plt.legend()
plt.show()

# %%
# Функция для расчёта MSE
def compute_mse(y_true, y_pred):
    """
    y_true, y_pred: массивы NumPy одинаковой формы
    """
    y_true = y_true.reshape(-1, 1)
    y_pred = y_pred.reshape(-1, 1)
    return float(np.mean((y_true - y_pred) ** 2))

# %%
# Моделирование работы НС (получение предсказаний)
pred_test = model_sin.predict(X_train, verbose=0).ravel()

# Расчёт MSE на обучающей выборке
train_mse = compute_mse(y_train, pred_test)
print(f"MSE (train) = {train_mse:.6f}")

# %%
# Вывод графиков с результатом моделирования
plt.figure(figsize=(10, 5))
plt.plot(t0, x, 'b', linewidth=5, label='SIN')
plt.plot(t0, pred_test, 'r', linewidth=3, label='SIN_NN')
plt.title("График функции", fontsize=16)
plt.ylabel('Y axis', fontsize=14)
plt.xlabel('X axis', fontsize=14)
plt.grid()
plt.legend(loc="upper right")
plt.show()

# %%
# Тестирование на данных, не входящих в обучающую выборку
t0_test = np.arange(0, 2, 0.001, dtype=np.float32)
t_test  = 2 * math.pi * t0_test
x_test  = np.sin(t_test).astype(np.float32)

X_test = t0_test.reshape(-1, 1)
y_test = x_test.reshape(-1, 1)

# Моделирование работы НС (получение предсказаний)
y_test_pred = model_sin.predict(X_test, verbose=0).ravel()

# Расчёт MSE на тестовой выборке
test_mse = compute_mse(y_test, y_test_pred)
print(f"MSE (test, NNSin) = {test_mse:.6f}")

# %%
plt.figure(figsize=(10, 5))
plt.plot(t0_test, x_test, 'b', label='SIN', linewidth=5)
plt.plot(t0_test, y_test_pred, 'r', label='SIN_NN', linewidth=3)
plt.title("График функции (тестовый интервал)", fontsize=16)
plt.ylabel('Y axis', fontsize=14)
plt.xlabel('X axis', fontsize=14)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Лабораторная работа №2. Часть 2

# %% [markdown]
# ## Теоретические сведения
# ### Ветвящиеся архитектуры
#
# Для решения более сложных задач простой последовательной цепочки слоёв может быть недостаточно. Иногда сети необходимо выделить общую скрытую репрезентацию входа, а затем обработать её параллельно, чтобы извлечь независимые группы признаков.
#
# Ветвящаяся архитектура строится следующим образом:
# 1. **Общая часть (Shared part):** Входные данные проходят через один или несколько общих слоёв.
# 2. **Ветви (Branches):** Выход общей части подаётся одновременно на входы нескольких независимых слоёв (веток). Каждая ветвь обучается выделять «свои» специфические закономерности.
# 3. **Объединение (Merge):** Результаты вычислений из всех ветвей объединяются (чаще всего с помощью конкатенации тензоров по признаковому измерению).
# 4. **Выходной слой:** Объединённый тензор подаётся на финальный слой для получения итогового предсказания.
#
# В Keras такая логика реализуется в Functional API: вы один раз пропускаете вход через общие слои, сохраняете результат в промежуточную переменную, затем подаёте её в каждую ветвь. Результаты ветвей объединяются функцией `concatenate`.
#
# Одним из классических примеров ветвящейся архитектуры является Unet для задач сегментации изображений. В ней:
#
# - **энкодер** (нисходящая часть) поэтапно уменьшает размер карты признаков, увеличивая число каналов и извлекая всё более абстрактные признаки;
# - **декодер** (восходящая часть) восстанавливает пространственное разрешение с помощью операций upsampling / transposed‑conv;
# - между соответствующими уровнями энкодера и декодера используются **skip‑соединения**: карты признаков из энкодера конкатенируются с картами декодера. Таким образом реализуются ветви, которые передают в декодер как высокоуровневые признаки, так и детальную пространственную информацию.
#
# С точки зрения общей схемы, Unet как раз иллюстрирует идею *общей части + нескольких ветвей + объединения (concatenate)*, только в более сложном, многоуровневом варианте.
#
# ![image.png](data:image/png;base64,...)

# %%
# Ветвящаяся модель для аппроксимации функции
def NN_sin_branch(in_shape):
    model_input = Input(shape=in_shape)

    # основная ветка
    x_main = Dense(50, activation="relu")(model_input)
    x_main = Dense(50, activation="relu")(x_main)

    # параллельная ветка
    x_branch = Dense(50, activation="sigmoid")(model_input)

    # объединение ветвей
    x_concat = concatenate([x_main, x_branch])

    # выходной слой
    model_out = Dense(1)(x_concat)

    model = Model(model_input, model_out, name="BranchSin_Functional")
    model.compile(optimizer=Adam(learning_rate=0.01), loss="mse")
    return model

# %%
# Создание модели
model_branch = NN_sin_branch((1,))

print("\n=== Структура ветвящейся модели (Keras) ===")
model_branch.summary()
utils.plot_model(model_branch, dpi=60, show_shapes=True)

# %%
# Подготовка данных для Keras
X_train = t0.reshape(-1, 1)
y_train = x.reshape(-1, 1)

# Параметры обучения
n_epochs   = 100
batch_size = 30

history_branch_obj = model_branch.fit(
    X_train, y_train,
    epochs=n_epochs,
    batch_size=batch_size,
    verbose=0
)
history_branch = history_branch_obj.history['loss']

for epoch in range(19, n_epochs, 20):
    print(f"[Branch] Epoch {epoch+1:3d}/{n_epochs}, loss = {history_branch[epoch]:.6f}")

# %%
# Моделирование работы ветвящейся НС (обучающий интервал)
pred_branch_train = model_branch.predict(X_train, verbose=0).ravel()

# Расчёт MSE на обучающей выборке для ветвящейся сети
branch_train_mse = compute_mse(y_train, pred_branch_train)
print(f"MSE (train, BranchSin) = {branch_train_mse:.6f}")

plt.figure(figsize=(10, 5))
plt.plot(t0, x, 'b', linewidth=5, label='SIN')
plt.plot(t0, pred_branch_train, 'g', linewidth=3, label='SIN_BranchNN')
plt.title("График функции (ветвящаяся сеть, обучающий интервал)", fontsize=16)
plt.ylabel('Y axis', fontsize=14)
plt.xlabel('X axis', fontsize=14)
plt.grid()
plt.legend(loc="upper right")

# %%
# Тестирование на данных, не входящих в обучающую выборку
t0_test = np.arange(0, 2, 0.001, dtype=np.float32)
t_test  = 2 * math.pi * t0_test
x_test  = np.sin(t_test).astype(np.float32)

X_test = t0_test.reshape(-1, 1)
y_test = x_test.reshape(-1, 1)

y_branch_test = model_branch.predict(X_test, verbose=0).ravel()

# Расчёт MSE на тестовом интервале для ветвящейся сети
branch_test_mse = compute_mse(y_test, y_branch_test)
print(f"MSE (test, BranchSin) = {branch_test_mse:.6f}")

plt.figure(figsize=(10, 5))
plt.plot(t0_test, x_test, 'b', label='SIN', linewidth=5)
plt.plot(t0_test, y_branch_test, 'g', label='SIN_BranchNN', linewidth=3)
plt.title("График функции (ветвящаяся сеть, тестовый интервал)", fontsize=16)
plt.ylabel('Y axis', fontsize=14)
plt.xlabel('X axis', fontsize=14)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Порядок выполнения работы

# %% [markdown]
# 1. Студент выбирает номер варианта согласно списку группы.
# 2. По номеру варианта выбирается целевая **нелинейная** функция \(Y=f(X)\) из таблицы вариантов.
# 3. Сгенерировать обучающую выборку \((X, Y)\) на интервале, указанном преподавателем (например, \(X \in [0, 2\pi]\)), добавить тестовый интервал, не пересекающийся с обучающим.
# 4. Реализовать в Keras две модели:
#    - последовательную полносвязную сеть (NNSin);
#    - ветвящуюся сеть (BranchSin) с двумя параллельными ветвями и последующей конкатенацией признаков.
# 5. Обучить обе сети на одной и той же выборке, подобрать гиперпараметры (число эпох, размер батча, скорость обучения) так, чтобы добиться разумной аппроксимации функции.
# 6. Сравнить качество:
#    - по графикам на обучающем и тестовом интервале;
#    - по числовым метрикам (MSE на обучающей и тестовой выборках);
#    - по сложности модели (число параметров), форме графа сети (`model.summary()` / `utils.plot_model`).
# 7. Заполнить таблицу экспериментов, сделать краткие выводы о влиянии архитектуры (последовательная vs ветвящаяся) и гиперпараметров на качество аппроксимации.

# %% [markdown]
# ### Таблица вариантов
#
# | № варианта | Функция              | № варианта | Функция                    |
# |-----------:|----------------------|-----------:|----------------------------|
# | 1          | Y = 5sin(X+3)        | 26         | Y = 2sin(X) - 5            |
# | 2          | Y = sin(X)           | 27         | Y = sin(X) + 6             |
# | 3          | Y = cos(X)/sin(X)    | 28         | Y = cos(X)*3sin(X)         |
# | 4          | Y = 4X^2 + 1         | 29         | Y = sin(X) + 10            |
# | 5          | Y = cos(X)           | 30         | Y = 2cos(X)sin(X)          |
# | 6          | Y = cos(X)/2         | 31         | Y = 15X^2 - 4              |
# | 7          | Y = tan(X)           | 32         | Y = 3tan(X)                |
# | 8          | Y = cot(X)           | 33         | Y = 2 + sin(X)             |
# | 9          | Y = 2sin(X)          | 34         | Y = 2sin(X-6) - 5          |
# | 10         | Y = X^2 + 5          | 35         | Y = X^2 - 6                |
# | 11         | Y = cos(X)/sin(X)    | 36         | Y = cos(X)/(3sin(X))       |
# | 12         | Y = sin(X) + 5       | 37         | Y = sin(X) - 2             |
# | 13         | Y = cos(X)sin(X)     | 38         | Y = 2cos(X)                |
# | 14         | Y = 15X^2            | 39         | Y = 5X^2 - 4               |
# | 15         | Y = 2tan(X)          | 40         | Y = tan(X)/3               |
# | 16         | Y = 1 + sin(X)       | 41         | Y = 2 + 3sin(X)            |
# | 17         | Y = 4X^2 + 3         | 42         | Y = 2sin(X) + 3            |
# | 18         | Y = cos(X)/10        | 43         | Y = 3X^2 + 6               |
# | 19         | Y = cos(X)/6         | 44         | Y = cos(X)*4sin(X)         |
# | 20         | Y = 4tan(X)          | 45         | Y = sin(X) - 5             |
# | 21         | Y = 2cot(X)          | 46         | Y = 0.5cos(X)sin(X)        |
# | 22         | Y = X^2 - 4          | 47         | Y = 5X^2 - 3               |
# | 23         | Y = 2sin(X+1)        | 48         | Y = cos(X) + sin(2X)       |
# | 24         | Y = sin(2X)          | 49         | Y = cos(2X) + 1            |
# | 25         | Y = 3cos(X+2)        | 50         | Y = sin(X)cos(2X)          |
#
# Примечание. При работе с функциями tan(X) и cot(X) выбирайте такой диапазон X,
# чтобы избежать точек разрыва и деления на ноль (например, не брать точки
# в окрестности X = π/2 + kπ, k ∈ Z).

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, concatenate
from tensorflow.keras.optimizers import Adam

# Обучающая выборка
X_train = np.arange(-1.3, 1.3, 0.01, dtype=np.float32).reshape(-1, 1)
Y_train = (3 * X_train**2 + 6).astype(np.float32)

# Тестовая выборка
X_test = np.arange(1.5, 2.8, 0.01, dtype=np.float32).reshape(-1, 1)
Y_test = (2 * X_test**2 + 6).astype(np.float32)

# Визуализация
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(X_train, Y_train, 'b', label='train')
plt.title('Обучающий интервал')
plt.subplot(1,2,2)
plt.plot(X_test, Y_test, 'r', label='test')
plt.title('Тестовый интервал')
plt.show()

# %%
# Последовательная модель (NNSin)

def NNSin_seq():
    model = Sequential([
        Dense(50, activation='relu', input_shape=(1,)),
        Dense(50, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=0.002), loss='mse')
    return model

# Ветвящаяся модель (BranchSin)

def BranchSin():
    inp = Input(shape=(1,))
    # общая часть
    main = Dense(50, activation='relu')(inp)
    main = Dense(50, activation='relu')(main)
    # ветвь
    branch = Dense(50, activation='sigmoid')(inp)
    # объединение
    concat = concatenate([main, branch])
    out = Dense(1)(concat)
    model = Model(inp, out)
    model.compile(optimizer=Adam(learning_rate=0.002), loss='mse')
    return model

# %%
# Обучение моделей

model_seq = NNSin_seq()
history_seq = model_seq.fit(
    X_train, Y_train,
    epochs=400,
    batch_size=64,
    verbose=1
)

model_branch = BranchSin()
history_branch = model_branch.fit(
    X_train, Y_train,
    epochs=400,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.3532
# Epoch 2/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 54.7176
# Epoch 3/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 50.8636
# Epoch 4/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.3418
# Epoch 5/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.9231
# Epoch 6/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.3724
# Epoch 7/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.2827
# Epoch 8/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.9057
# Epoch 9/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.3475
# Epoch 10/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3310
# Epoch 11/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2468
# Epoch 12/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3477
# Epoch 13/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8815
# Epoch 14/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7866
# Epoch 15/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2633
# Epoch 16/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1459
# Epoch 17/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1559
# Epoch 18/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1704
# Epoch 19/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1508
# Epoch 20/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1114
# Epoch 21/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0702
# Epoch 22/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0481
# Epoch 23/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0443
# Epoch 24/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0439
# Epoch 25/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0383
# Epoch 26/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0314
# Epoch 27/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0281
# Epoch 28/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0266
# Epoch 29/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0246
# Epoch 30/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0221
# Epoch 31/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0208
# Epoch 32/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0197
# Epoch 33/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0188
# Epoch 34/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0180
# Epoch 35/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0173
# Epoch 36/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0169
# Epoch 37/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0166
# Epoch 38/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0162
# Epoch 39/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0158
# Epoch 40/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0155
# Epoch 41/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0155
# Epoch 42/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153
# Epoch 43/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 44/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149
# Epoch 45/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0149
# Epoch 46/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149
# Epoch 47/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 48/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0147
# Epoch 49/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0147
# Epoch 50/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0146
# Epoch 51/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0144
# Epoch 52/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0144
# Epoch 53/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0145
# Epoch 54/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143
# Epoch 55/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0142
# Epoch 56/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143
# Epoch 57/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0144
# Epoch 58/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143
# Epoch 59/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 60/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143
# Epoch 61/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139
# Epoch 62/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139
# Epoch 63/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138
# Epoch 64/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138
# Epoch 65/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139
# Epoch 66/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138
# Epoch 67/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137
# Epoch 68/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135
# Epoch 69/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0136
# Epoch 70/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135
# Epoch 71/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 72/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135
# Epoch 73/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133
# Epoch 74/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133
# Epoch 75/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 76/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131
# Epoch 77/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135
# Epoch 78/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138
# Epoch 79/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0132
# Epoch 80/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133
# Epoch 81/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0134
# Epoch 82/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130
# Epoch 83/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131
# Epoch 84/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135
# Epoch 85/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134
# Epoch 86/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130
# Epoch 87/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0127
# Epoch 88/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0129
# Epoch 89/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0127
# Epoch 90/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133
# Epoch 91/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130
# Epoch 92/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126
# Epoch 93/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126
# Epoch 94/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130
# Epoch 95/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0128
# Epoch 96/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0123
# Epoch 97/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0122
# Epoch 98/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0121
# Epoch 99/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0121
# Epoch 100/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125
# Epoch 101/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0123
# Epoch 102/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0120
# Epoch 103/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0121
# Epoch 104/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0120
# Epoch 105/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0120
# Epoch 106/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0119
# Epoch 107/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118
# Epoch 108/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118
# Epoch 109/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0119
# Epoch 110/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0116
# Epoch 111/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118
# Epoch 112/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115
# Epoch 113/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0115
# Epoch 114/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0114
# Epoch 115/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0114
# Epoch 116/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0114
# Epoch 117/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0114
# Epoch 118/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115
# Epoch 119/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115
# Epoch 120/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139
# Epoch 121/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 122/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0117
# Epoch 123/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0113
# Epoch 124/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115
# Epoch 125/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0117
# Epoch 126/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0113
# Epoch 127/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0110
# Epoch 128/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0116
# Epoch 129/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115
# Epoch 130/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 131/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109
# Epoch 132/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 133/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 134/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107
# Epoch 135/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0107
# Epoch 136/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0108
# Epoch 137/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0113
# Epoch 138/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0113
# Epoch 139/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 140/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0107
# Epoch 141/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0104
# Epoch 142/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110
# Epoch 143/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110
# Epoch 144/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0104
# Epoch 145/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0106
# Epoch 146/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0103
# Epoch 147/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 148/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0106
# Epoch 149/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102
# Epoch 150/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104
# Epoch 151/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0105
# Epoch 152/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105
# Epoch 153/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0105
# Epoch 154/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0102
# Epoch 155/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0099
# Epoch 156/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0104
# Epoch 157/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0109
# Epoch 158/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0103
# Epoch 159/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0104
# Epoch 160/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0106
# Epoch 161/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0104
# Epoch 162/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0105
# Epoch 163/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0100
# Epoch 164/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101
# Epoch 165/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0100
# Epoch 166/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0097
# Epoch 167/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0097
# Epoch 168/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0095
# Epoch 169/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0095
# Epoch 170/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0097
# Epoch 171/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0095
# Epoch 172/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0094
# Epoch 173/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0094
# Epoch 174/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0093
# Epoch 175/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093
# Epoch 176/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092
# Epoch 177/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092
# Epoch 178/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093
# Epoch 179/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0095
# Epoch 180/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0098
# Epoch 181/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092
# Epoch 182/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0092
# Epoch 183/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093
# Epoch 184/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0091
# Epoch 185/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0093
# Epoch 186/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0091
# Epoch 187/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0091
# Epoch 188/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097
# Epoch 189/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097
# Epoch 190/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0091
# Epoch 191/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0091
# Epoch 192/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090
# Epoch 193/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 194/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 195/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 196/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 197/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090
# Epoch 198/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087
# Epoch 199/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088
# Epoch 200/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089
# Epoch 201/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087
# Epoch 202/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0086
# Epoch 203/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 204/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089
# Epoch 205/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 206/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0091
# Epoch 207/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0095
# Epoch 208/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 209/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 210/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 211/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 212/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 213/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0083
# Epoch 214/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0083
# Epoch 215/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 216/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 217/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 218/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 219/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 220/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 221/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081
# Epoch 222/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 223/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0084
# Epoch 224/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 225/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085
# Epoch 226/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 227/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079
# Epoch 228/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 229/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0085
# Epoch 230/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079
# Epoch 231/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 232/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0083
# Epoch 233/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0084
# Epoch 234/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 235/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 236/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 237/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079
# Epoch 238/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 239/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 240/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 241/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079
# Epoch 242/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 243/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 244/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 245/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085
# Epoch 246/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 247/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079
# Epoch 248/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 249/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 250/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 251/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 252/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 253/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 254/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 255/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077
# Epoch 256/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 257/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074
# Epoch 258/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 259/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 260/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077
# Epoch 261/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0084
# Epoch 262/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 263/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0083
# Epoch 264/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 265/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 266/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 267/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 268/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 269/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 270/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073
# Epoch 271/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 272/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072
# Epoch 273/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 274/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072
# Epoch 275/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 276/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075
# Epoch 277/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0072
# Epoch 278/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 279/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 280/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 281/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070
# Epoch 282/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072
# Epoch 283/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 284/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 285/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 286/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 287/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 288/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 289/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 290/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 291/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0067
# Epoch 292/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 293/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 294/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 295/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 296/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 297/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 298/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085
# Epoch 299/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073
# Epoch 300/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 301/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 302/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 303/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0080
# Epoch 304/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 305/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 306/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068
# Epoch 307/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 308/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 309/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073
# Epoch 310/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065
# Epoch 311/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 312/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0067
# Epoch 313/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 314/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 315/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 316/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 317/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 318/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 319/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 320/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068
# Epoch 321/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0067
# Epoch 322/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 323/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064
# Epoch 324/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0066
# Epoch 325/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065
# Epoch 326/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0063
# Epoch 327/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065
# Epoch 328/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065
# Epoch 329/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0064
# Epoch 330/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0063
# Epoch 331/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0064
# Epoch 332/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0063
# Epoch 333/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0063
# Epoch 334/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065
# Epoch 335/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0064
# Epoch 336/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0064
# Epoch 337/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0061
# Epoch 338/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0066
# Epoch 339/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0067
# Epoch 340/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0064
# Epoch 341/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0064
# Epoch 342/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0063
# Epoch 343/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0069
# Epoch 344/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0070
# Epoch 345/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0069
# Epoch 346/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0062
# Epoch 347/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0073
# Epoch 348/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0068
# Epoch 349/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0061
# Epoch 350/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062
# Epoch 351/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 352/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062
# Epoch 353/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068
# Epoch 354/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0060
# Epoch 355/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063
# Epoch 356/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 357/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0062
# Epoch 358/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062
# Epoch 359/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 360/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 361/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 362/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 363/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063
# Epoch 364/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 365/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092
# Epoch 366/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067
# Epoch 367/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0067
# Epoch 368/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 369/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 370/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059
# Epoch 371/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059
# Epoch 372/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 373/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0060
# Epoch 374/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092
# Epoch 375/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 376/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0082
# Epoch 377/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 378/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065
# Epoch 379/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064
# Epoch 380/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057
# Epoch 381/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 382/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059
# Epoch 383/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056
# Epoch 384/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057
# Epoch 385/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0055
# Epoch 386/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061
# Epoch 387/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056
# Epoch 388/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059
# Epoch 389/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0059
# Epoch 390/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 391/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 392/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 393/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057
# Epoch 394/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057
# Epoch 395/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058
# Epoch 396/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056
# Epoch 397/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056
# Epoch 398/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0057
# Epoch 399/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063
# Epoch 400/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057
# Epoch 1/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 54.4404
# Epoch 2/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 48.0690
# Epoch 3/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 41.9918
# Epoch 4/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.8302
# Epoch 5/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 29.7449
# Epoch 6/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.5450
# Epoch 7/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.2426
# Epoch 8/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.4543
# Epoch 9/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5182
# Epoch 10/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8362
# Epoch 11/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8712
# Epoch 12/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3615
# Epoch 13/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4927
# Epoch 14/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5435
# Epoch 15/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3738
# Epoch 16/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1940
# Epoch 17/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1214
# Epoch 18/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1149
# Epoch 19/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1228
# Epoch 20/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1161
# Epoch 21/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0974
# Epoch 22/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0832
# Epoch 23/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0773
# Epoch 24/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0738
# Epoch 25/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0700
# Epoch 26/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0655
# Epoch 27/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0619
# Epoch 28/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0596
# Epoch 29/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0574
# Epoch 30/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0549
# Epoch 31/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0538
# Epoch 32/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0532
# Epoch 33/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0518
# Epoch 34/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0509
# Epoch 35/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0500
# Epoch 36/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0492
# Epoch 37/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0488
# Epoch 38/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0488
# Epoch 39/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0484
# Epoch 40/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0480
# Epoch 41/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0478
# Epoch 42/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0477
# Epoch 43/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0472
# Epoch 44/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0471
# Epoch 45/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0478
# Epoch 46/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0487
# Epoch 47/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0490
# Epoch 48/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0470
# Epoch 49/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0477
# Epoch 50/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0488
# Epoch 51/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0481
# Epoch 52/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0465
# Epoch 53/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0462
# Epoch 54/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0471
# Epoch 55/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0471
# Epoch 56/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0462
# Epoch 57/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0456
# Epoch 58/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0463
# Epoch 59/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0464
# Epoch 60/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0457
# Epoch 61/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0454
# Epoch 62/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0464
# Epoch 63/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0463
# Epoch 64/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0445
# Epoch 65/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0456
# Epoch 66/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0465
# Epoch 67/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0450
# Epoch 68/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0440
# Epoch 69/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0452
# Epoch 70/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0463
# Epoch 71/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0458
# Epoch 72/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0450
# Epoch 73/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0442
# Epoch 74/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0435
# Epoch 75/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0440
# Epoch 76/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0450
# Epoch 77/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0446
# Epoch 78/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0431
# Epoch 79/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0435
# Epoch 80/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0447
# Epoch 81/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0446
# Epoch 82/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0437
# Epoch 83/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0425
# Epoch 84/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0436
# Epoch 85/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0445
# Epoch 86/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0430
# Epoch 87/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0419
# Epoch 88/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0420
# Epoch 89/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0421
# Epoch 90/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0421
# Epoch 91/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0420
# Epoch 92/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0416
# Epoch 93/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0416
# Epoch 94/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0420
# Epoch 95/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0431
# Epoch 96/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0424
# Epoch 97/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0411
# Epoch 98/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0408
# Epoch 99/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0436
# Epoch 100/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0455
# Epoch 101/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0424
# Epoch 102/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0402
# Epoch 103/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0419
# Epoch 104/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0433
# Epoch 105/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0417
# Epoch 106/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0404
# Epoch 107/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0396
# Epoch 108/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0403
# Epoch 109/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0399
# Epoch 110/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0392
# Epoch 111/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0406
# Epoch 112/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0400
# Epoch 113/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0390
# Epoch 114/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0403
# Epoch 115/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0395
# Epoch 116/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0387
# Epoch 117/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0388
# Epoch 118/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0383
# Epoch 119/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0383
# Epoch 120/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0386
# Epoch 121/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0390
# Epoch 122/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0380
# Epoch 123/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0372
# Epoch 124/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0380
# Epoch 125/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0392
# Epoch 126/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0393
# Epoch 127/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0379
# Epoch 128/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0368
# Epoch 129/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0363
# Epoch 130/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0364
# Epoch 131/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0366
# Epoch 132/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0367
# Epoch 133/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0365
# Epoch 134/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0377
# Epoch 135/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0372
# Epoch 136/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0378
# Epoch 137/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0375
# Epoch 138/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0384
# Epoch 139/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0374
# Epoch 140/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0357
# Epoch 141/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0362
# Epoch 142/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0357
# Epoch 143/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0354
# Epoch 144/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0340
# Epoch 145/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0362
# Epoch 146/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0347
# Epoch 147/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0338
# Epoch 148/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0338
# Epoch 149/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0345
# Epoch 150/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0367
# Epoch 151/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0344
# Epoch 152/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0337
# Epoch 153/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0348
# Epoch 154/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0327
# Epoch 155/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0353
# Epoch 156/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0353
# Epoch 157/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0324
# Epoch 158/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0332
# Epoch 159/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0336
# Epoch 160/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0318
# Epoch 161/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0316
# Epoch 162/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0317
# Epoch 163/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0317
# Epoch 164/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0324
# Epoch 165/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0313
# Epoch 166/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0310
# Epoch 167/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0308
# Epoch 168/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0308
# Epoch 169/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0315
# Epoch 170/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0312
# Epoch 171/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0305
# Epoch 172/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0344
# Epoch 173/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0331
# Epoch 174/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0316
# Epoch 175/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0309
# Epoch 176/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0306
# Epoch 177/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0293
# Epoch 178/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0304
# Epoch 179/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0301
# Epoch 180/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0303
# Epoch 181/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0288
# Epoch 182/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0287
# Epoch 183/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0286
# Epoch 184/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0284
# Epoch 185/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0284
# Epoch 186/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0279
# Epoch 187/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0285
# Epoch 188/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0288
# Epoch 189/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0277
# Epoch 190/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0276
# Epoch 191/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0293
# Epoch 192/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0289
# Epoch 193/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0276
# Epoch 194/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0273
# Epoch 195/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0286
# Epoch 196/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0271
# Epoch 197/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0272
# Epoch 198/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0272
# Epoch 199/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0265
# Epoch 200/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0279
# Epoch 201/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0293
# Epoch 202/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0273
# Epoch 203/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0335
# Epoch 204/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0274
# Epoch 205/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0298
# Epoch 206/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0274
# Epoch 207/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0251
# Epoch 208/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0260
# Epoch 209/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0246
# Epoch 210/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0250
# Epoch 211/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0251
# Epoch 212/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0252
# Epoch 213/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0245
# Epoch 214/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0241
# Epoch 215/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0241
# Epoch 216/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0240
# Epoch 217/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0241
# Epoch 218/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0251
# Epoch 219/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0247
# Epoch 220/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0238
# Epoch 221/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0264
# Epoch 222/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0231
# Epoch 223/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0233
# Epoch 224/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0230
# Epoch 225/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0232
# Epoch 226/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0237
# Epoch 227/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0234
# Epoch 228/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0224
# Epoch 229/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0221
# Epoch 230/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0225
# Epoch 231/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0228
# Epoch 232/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0225
# Epoch 233/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0239
# Epoch 234/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0215
# Epoch 235/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0220
# Epoch 236/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0217
# Epoch 237/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0215
# Epoch 238/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0212
# Epoch 239/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0211
# Epoch 240/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0221
# Epoch 241/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0243
# Epoch 242/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0206
# Epoch 243/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0222
# Epoch 244/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0222
# Epoch 245/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0204
# Epoch 246/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0204
# Epoch 247/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0198
# Epoch 248/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0200
# Epoch 249/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0196
# Epoch 250/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0208
# Epoch 251/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0206
# Epoch 252/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0206
# Epoch 253/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0201
# Epoch 254/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0198
# Epoch 255/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0198
# Epoch 256/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0195
# Epoch 257/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0186
# Epoch 258/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0185
# Epoch 259/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0183
# Epoch 260/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0184
# Epoch 261/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0186
# Epoch 262/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0195
# Epoch 263/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0182
# Epoch 264/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0179
# Epoch 265/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0185
# Epoch 266/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0181
# Epoch 267/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0178
# Epoch 268/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0176
# Epoch 269/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0184
# Epoch 270/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0185
# Epoch 271/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0182
# Epoch 272/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191
# Epoch 273/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0169
# Epoch 274/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0163
# Epoch 275/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0167
# Epoch 276/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0157
# Epoch 277/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0172
# Epoch 278/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0171
# Epoch 279/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0185
# Epoch 280/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0166
# Epoch 281/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0164
# Epoch 282/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0166
# Epoch 283/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0153
# Epoch 284/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0151
# Epoch 285/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0166
# Epoch 286/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0159
# Epoch 287/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0158
# Epoch 288/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0147
# Epoch 289/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146
# Epoch 290/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0142
# Epoch 291/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0149
# Epoch 292/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0145
# Epoch 293/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0143
# Epoch 294/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0142
# Epoch 295/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0141
# Epoch 296/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 297/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0144
# Epoch 298/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0136
# Epoch 299/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146
# Epoch 300/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0149
# Epoch 301/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0130
# Epoch 302/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0141
# Epoch 303/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0144
# Epoch 304/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137
# Epoch 305/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0147
# Epoch 306/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0142
# Epoch 307/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0148
# Epoch 308/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0128
# Epoch 309/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0129
# Epoch 310/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0120
# Epoch 311/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0132
# Epoch 312/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125
# Epoch 313/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143
# Epoch 314/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0134
# Epoch 315/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110
# Epoch 316/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118
# Epoch 317/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0120
# Epoch 318/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0115
# Epoch 319/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0117
# Epoch 320/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110
# Epoch 321/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0111
# Epoch 322/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0108
# Epoch 323/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0111
# Epoch 324/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0103
# Epoch 325/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0122
# Epoch 326/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0106
# Epoch 327/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0117
# Epoch 328/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0102
# Epoch 329/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0105
# Epoch 330/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0108
# Epoch 331/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0103
# Epoch 332/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0100
# Epoch 333/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097
# Epoch 334/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0101
# Epoch 335/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0093
# Epoch 336/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095
# Epoch 337/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0094
# Epoch 338/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0097
# Epoch 339/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0092
# Epoch 340/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0098
# Epoch 341/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0099
# Epoch 342/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0098
# Epoch 343/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0085
# Epoch 344/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0087
# Epoch 345/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088
# Epoch 346/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0120
# Epoch 347/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0115
# Epoch 348/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0116
# Epoch 349/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088
# Epoch 350/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088
# Epoch 351/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0086
# Epoch 352/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0079
# Epoch 353/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 354/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0079
# Epoch 355/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0074
# Epoch 356/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076
# Epoch 357/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077
# Epoch 358/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0072
# Epoch 359/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072
# Epoch 360/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073
# Epoch 361/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0084
# Epoch 362/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0066
# Epoch 363/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0093
# Epoch 364/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073
# Epoch 365/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0074
# Epoch 366/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0066
# Epoch 367/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0067
# Epoch 368/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0071
# Epoch 369/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065
# Epoch 370/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0067
# Epoch 371/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061
# Epoch 372/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066
# Epoch 373/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0060
# Epoch 374/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059
# Epoch 375/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064
# Epoch 376/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058
# Epoch 377/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 378/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056
# Epoch 379/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 380/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0058
# Epoch 381/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0061
# Epoch 382/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0057
# Epoch 383/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0053
# Epoch 384/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0062
# Epoch 385/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0054
# Epoch 386/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0060
# Epoch 387/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0073
# Epoch 388/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0056
# Epoch 389/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0054
# Epoch 390/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0055
# Epoch 391/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0049
# Epoch 392/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051
# Epoch 393/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0054
# Epoch 394/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0049
# Epoch 395/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0058
# Epoch 396/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0050
# Epoch 397/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0061
# Epoch 398/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0049
# Epoch 399/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0050
# Epoch 400/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0045

# %%
# Функция для расчёта MSE
def compute_mse(y_true, y_pred):
    """
    y_true, y_pred: массивы NumPy одинаковой формы
    """
    y_true = y_true.reshape(-1, 1)
    y_pred = y_pred.reshape(-1, 1)
    return float(np.mean((y_true - y_pred) ** 2))

# %%
# Sequential
y_pred_train_seq = model_seq.predict(X_train, verbose=0)
y_pred_test_seq = model_seq.predict(X_test, verbose=0)

mse_train_seq = compute_mse(Y_train, y_pred_train_seq)
mse_test_seq = compute_mse(Y_test, y_pred_test_seq)

print("Sequential")
print("Train MSE:", mse_train_seq)
print("Test MSE :", mse_test_seq)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(X_train, Y_train, label="True")
plt.plot(X_train, y_pred_train_seq, '--', label="Predict")
plt.title("Train")
plt.legend()

plt.subplot(1,2,2)
plt.plot(X_test, Y_test, label="True")
plt.plot(X_test, y_pred_test_seq, '--', label="Predict")
plt.title("Test")
plt.legend()

plt.show()


# Branch
y_pred_train_branch = model_branch.predict(X_train, verbose=0)
y_pred_test_branch = model_branch.predict(X_test, verbose=0)

mse_train_branch = compute_mse(Y_train, y_pred_train_branch)
mse_test_branch = compute_mse(Y_test, y_pred_test_branch)

print("\nBranch")
print("Train MSE:", mse_train_branch)
print("Test MSE :", mse_test_branch)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(X_train, Y_train, label="True")
plt.plot(X_train, y_pred_train_seq, '--', label="Predict")
plt.title("Train")
plt.legend()

plt.subplot(1,2,2)
plt.plot(X_test, Y_test, label="True")
plt.plot(X_test, y_pred_test_seq, '--', label="Predict")
plt.title("Test")
plt.legend()

plt.show()
# Out:
# Sequential
# Train MSE: 0.005787838250398636
# Test MSE : 1.325764775276184
# Branch
# Train MSE: 0.004462376236915588
# Test MSE : 1.2410290241241455

# %%
print("=== Структура модели (NNSin) ===")
model_seq.summary()

print("\n=== Структура ветвящейся модели (BranchSin) ===")
model_branch.summary()
# Out:
# === Структура модели (NNSin) ===
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_82 (Dense)                │ (None, 50)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_83 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_84 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,105 (31.66 KB)
#  Trainable params: 2,701 (10.55 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,404 (21.11 KB)
# === Структура ветвящейся модели (BranchSin) ===
# Model: "functional_24"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_25      │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_85 (Dense)    │ (None, 50)        │        100 │ input_layer_25[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_86 (Dense)    │ (None, 50)        │      2,550 │ dense_85[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_87 (Dense)    │ (None, 50)        │        100 │ input_layer_25[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 100)       │          0 │ dense_86[0][0],   │
# │ (Concatenate)       │                   │            │ dense_87[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_88 (Dense)    │ (None, 1)         │        101 │ concatenate_10[0… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,555 (33.42 KB)
#  Trainable params: 2,851 (11.14 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,704 (22.29 KB)

# %% [markdown]
# ### Сравнительная таблица экспериментов
#
# #### Модель 1: NNSin (последовательная)
#
#
# | № эксп. | Описание настройки (слои, LR, batch, эпохи)  | MSE train | MSE test |
# | -------------- | -------------------------------------------- | --------- | -------- |
# | 1              | 2 слоя по 50, lr=0.01, batch=16, epochs=100  | 0.00083   | 1.508    |
# | 2              | 2 слоя по 50, lr=0.005, batch=32, epochs=200 | 0.00217   | 1.297    |
# | 3              | 2 слоя по 100, lr=0.01, batch=16, epochs=100 | 0.00382   | 1.838    |
# | 4              | 2 слоя по 50, lr=0.001, batch=64, epochs=250 | 0.007     | 1.276    |
# | 5              | 2 слоя по 50, lr=0.001, batch=64, epochs=400 | 0.0057    | 1.325    |
#
# #### Модель 2: BranchSin (ветвящаяся)
#
#
# | № эксп. | Описание настройки (слои, LR, batch, эпохи)                  | MSE train | MSE test |
# | -------------- | ------------------------------------------------------------ | --------- | -------- |
# | 1              | Общая часть 2x50, ветвь 1x50, lr=0.01, batch=16, epochs=100  | 0.00017   | 2.194    |
# | 2              | Общая часть 2x50, ветвь 1x50, lr=0.005, batch=32, epochs=200 | 0.00021   | 2.118    |
# | 3              | Общая часть 2x100, ветвь 1x50, lr=0.01, batch=16, epochs=100 | 0.00002   | 2.643    |
# | 4              | Общая часть 2x50, ветвь 1x50, lr=0.001, batch=64, epochs=250 | 0.0025    | 1.302    |
# | 5              | Общая часть 2x50, ветвь 1x50, lr=0.001, batch=64, epochs=400 | 0.0044    | 1.241    |
#
#
# #### Общий вывод по моделям
#
#
# | Модель    | Лучшая конфигурация (кратко)                                 | Лучший MSE train | Лучший MSE test | Итоговый вывод (1–2 предложения)                                                               |
# | --------- | ------------------------------------------------------------ | ---------------- | --------------- | ---------------------------------------------------------------------------------------------- |
# | NNSin     | 2 слоя по 50, lr=0.001, batch=64, epochs=250                 | 0.007          | 1.276           | Лучше для аппроксимации функций, т.к. обучение более стабильное                                |
# | BranchSin | Общая часть 2x50, ветвь 1x50, lr=0.001, batch=64, epochs=400 | 0.0044          | 1.241           | Более сложная модель, чувствительнее к гиперпараметрам, нет значимых преимуществ над последовательной |
#
# ##### Вывод
# Ветвящаяся архитектура, как и последовательная, успешно решает задачу аппроксимации нелинейной функции. Также она оказалась более чувствительной к выбору гиперпараметров. При неудачных настройках качество заметно ухудшается, при этом последовательная модель демонстрирует более стабильные результаты.
#
# В проведённых экспериментах ветвящаяся модель не показала существенного преимущества по качеству аппроксимации, несмотря на более сложную структуру модели. Поэтому для данной задачи использовать последовательную сеть более рационально.

# %% [markdown]
# ## Контрольные вопросы
#
# 1. Чем отличается реализация модели в `Sequential` и в `Functional API` Keras, и в каких случаях функциональный подход предпочтительнее?
#
#   `Sequential` используется для последовательного соединения слоёв, когда каждый слой имеет только один вход и один выход. Такой способ прост в реализации и подходит для большинства базовых задач.
#
#   `Functional API` позволяет строить модели с несколькими входами и выходами, создавать ветвления, объединения слоёв и более сложные архитектуры. Поэтому функциональный подход лучше подходит для создания сложных нейронных сетей, например ветвящихся моделей.
#
# 2. Почему для задачи аппроксимации в данной работе используется функция потерь `mse`, и как по графику `loss` понять, что обучение проходит корректно?
#
#   Функция потерь `mse` (Mean Squared Error) измеряет среднеквадратичную разницу между истинными и предсказанными значениями. Она хорошо подходит для задач регрессии и аппроксимации функций, т.к. чувствительна к большим ошибкам. Если обучение проходит корректно, значение `loss` постепенно убывает и затем выходит на плато без резких скачков и роста.
#
# 3. Какие проблемы могут возникнуть при выборе слишком большого или слишком маленького `learning_rate` для оптимизатора Adam?
#
#   При слишком большом значении `learning_rate` оптимизатор может перескакивать минимум функции потерь, из-за чего обучение становится нестабильным или вообще не сходится.
#
#   При слишком маленьком `learning_rate` обучение происходит очень медленно, требуется значительно больше эпох, а сеть может застрять в локальном минимуме.
#
# 4. Как влияет размер батча (`batch_size`) на скорость обучения и стабильность аппроксимации функции?
#
# Малый размер батча чаще обновляет веса модели, что может улучшить качество обучения, но делает процесс более шумным и увеличивает время обучения.
#
# Большой `batch_size` ускоряет вычисления и делает обновления более плавными, однако может ухудшить качество обобщения и потребовать большего числа эпох. Также требуется больше памяти.
#
# 5. По каким признакам на графиках и по метрикам MSE можно сделать вывод, что ветвящаяся модель лучше (или хуже) последовательной?
#
# Сравнение проводится по графикам аппроксимации и значениям MSE на обучающей и тестовой выборках. Лучшей считается модель, у которой предсказанная кривая точнее совпадает с исходной функцией и меньше значение MSE на тестовой выборке. Если улучшение качества незначительно, но модель имеет более сложную структуру и большее число параметров, то её использование может быть нецелесообразным.
